# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge,Lasso

# %%
dataset = pd.read_csv(r'datadata.txt')
dataset
# Out:
#    X    y
# 0   1    2
# 1   2    4
# 2   3    6
# 3   4    8

# %%
df = dataset.copy()
X = df.iloc[: ,:-1]
y = df.iloc[: , -1]

# %%
X
# Out:
#    X
# 0   1
# 1   2
# 2   3
# 3   4

# %%
y
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name:  y , dtype: int64

# %%
lin = LinearRegression()
lin.fit(X,y)
# Out:
# LinearRegression()

# %%
l =5
Ridgee = Ridge(alpha = l)
Ridgee.fit(X,y)
# Out:
# Ridge(alpha=5)

# %%
Ridge_coeff = Ridgee.coef_  #w
Ridge_coeff
# Out:
# array([1.])

# %%
Ridge_intercept = Ridgee.intercept_ #b
Ridge_intercept
# Out:
# np.float64(2.5)

# %%
X_test = [1,2,3,4]
y_pred = Ridgee.predict(pd.DataFrame(X_test))
y_pred
# Out:
# c:\Users\habib\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
# array([3.5, 4.5, 5.5, 6.5])

# %%
plt.figure(figsize=(12,6) , dpi = 90)
plt.plot(X_test,y_pred , c ='r' , linewidth = 2)
plt.scatter(X,y)
plt.ylim(ymin = 0 , ymax = 9)
plt.xlim(xmin = 0 , xmax = 7)

# Add a text annotation to the last point of the regression line
plt.text(X_test[-1],y_pred[-1] # Position of text → last X point and its predicted Y
         , ' y = '   +    str('%.2f' %Ridge_coeff)  + ' * X +'  +  str('%.2f' %Ridge_intercept)    
                                                    +  '  For \u03BB or  \u03b1 = ' +    str(l)  ,   fontsize = 12)
plt.title('ridge Regression')
plt.show()
# Out:
# C:\Users\habib\AppData\Local\Temp\ipykernel_23312\243005523.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   , ' y = '   +    str('%.2f' %Ridge_coeff)  + ' * X +'  +  str('%.2f' %Ridge_intercept)
