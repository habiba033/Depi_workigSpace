# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r'C:\Users\habib\OneDrive\المستندات\Depi_workingSpace\Depi_workigSpace\Contents\ML\Salary_Data.csv')
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
plt.figure(figsize=( 3,3))
sns.pairplot(data, x_vars=["YearsExperience"], y_vars=["Salary"], size=8, kind="scatter")
plt.show()

# %%
print(data.columns.tolist()) # see the colmns titles
# Out:
# ['YearsExperience', 'Salary']

# %%
x= data.iloc[:,:-1]
y=data.iloc[:,1]

# %%
x_train , x_test , y_train ,y_test = train_test_split(x,y,test_size=0.2 , random_state=0)

# %%
my_model = LinearRegression()
my_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train , my_model.predict(x_train),color='red')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of experience')
plt.ylabel('Salary')
plt.show()

# %%
y_pred = my_model.predict(x_test)

plt.scatter(x_test,y_test , color = 'red')
plt.plot(x_train,my_model.predict(x_train), color='blue')

# %%
c= [i for i in range (1,len(y_test)+1)]
plt.plot(c,y_test,color='red')
plt.plot(c,y_pred,color = 'blue')
plt.title('Actual VS predictionn')
plt.xlabel('Number of employees')
plt.ylabel('Salary')
plt.show()

# %%
mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 12823412.298126549

# %%
rse = r2_score(y_test,y_pred)
rse
# Out:
# 0.988169515729126

# %%
my_model.intercept_ # b
# Out:
# np.float64(26780.09915062818)

# %%
my_model.coef_ #w
# Out:
# array([9312.57512673])

# %%
y_hat = (9312.57 * 7)+ 26780.1
y_hat
# Out:
# 91968.09

# %%
rms = np.sqrt(mse)
rms
# Out:
# np.float64(3580.979237321343)
